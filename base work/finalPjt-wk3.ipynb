# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.metrics import accuracy_score

import matplotlib as plt
#import tensorflow as tf

# %%
# matplotlib
# %matplotlib inline
import matplotlib
#matplotlib.rcParams.update({'font.size': 4})
matplotlib.rcParams["figure.dpi"] = 125

#set the font for matplotlib
from matplotlib import style
style.use('fivethirtyeight')

from matplotlib import figure
# Pandas and Numpy
import numpy as np
import pandas as pd
import pandas_profiling as pp

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import psycopg2

# %%
#import connection string (youll need to create this)
from config import conn

# create the engine
engine = create_engine(conn)
Base = automap_base()

# reflect an existing database into a new model
Base.prepare(engine, reflect=True)

# reflect the table
us_data = Base.classes.us_data_df_v3

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
#create df from Recession_Indicator table
results = []

results = session.query(us_data.intdate, \
                        us_data.ri, \
                        us_data.cpi, \
                        us_data.gdp, \
                        us_data.inf, \
                        us_data.unp, \
                        us_data.dji_open, \
                        us_data.dji_open_lag1, \
                        us_data.dji_open_lag7, \
                        us_data.dji_open_lag14, \
                        us_data.dji_open_lag30, \
                        us_data.dji_open_lag90, \
                        us_data.dji_open_lag365, \
                        us_data.dji_close, \
                        us_data.dji_close_lag1, \
                        us_data.dji_close_lag7, \
                        us_data.dji_close_lag14, \
                        us_data.dji_close_lag30, \
                        us_data.dji_close_lag90, \
                        us_data.dji_close_lag365, \
                        us_data.dji_opcl_diff, \
                        us_data.dji_opcl_diff_lag1, \
                        us_data.dji_opcl_diff_lag7, \
                        us_data.dji_opcl_diff_lag14, \
                        us_data.dji_opcl_diff_lag30, \
                        us_data.dji_opcl_diff_lag90, \
                        us_data.dji_opcl_diff_lag365, \
                        us_data.dji_high, \
                        us_data.dji_high_lag1, \
                        us_data.dji_high_lag7, \
                        us_data.dji_high_lag14, \
                        us_data.dji_high_lag30, \
                        us_data.dji_high_lag90, \
                        us_data.dji_high_lag365, \
                        us_data.dji_low, \
                        us_data.dji_low_lag1, \
                        us_data.dji_low_lag7, \
                        us_data.dji_low_lag14, \
                        us_data.dji_low_lag30, \
                        us_data.dji_low_lag90, \
                        us_data.dji_low_lag365, \
                        us_data.dji_hilo_diff, \
                        us_data.dji_hilo_diff_lag1, \
                        us_data.dji_hilo_diff_lag7, \
                        us_data.dji_hilo_diff_lag14, \
                        us_data.dji_hilo_diff_lag30, \
                        us_data.dji_hilo_diff_lag90, \
                        us_data.dji_hilo_diff_lag365
                       )


data_df = pd.DataFrame(results)
data_df.head()
# Out:
#     intdate     ri        cpi       gdp       inf       unp      dji_open  \
# 0  19701231  False  16.792044       NaN  5.838255       NaN  838.92000000
# 1  19710104  False  16.834236  1135.156  4.292767  5.994841  830.57000000
# 2  19710105  False  16.834236  1135.156  4.292767  5.997475  835.77000000
# 3  19710106  False  16.834236  1135.156  4.292767  6.007436  837.97000000
# 4  19710107  False  16.834236  1135.156  4.292767  6.121167  837.83000000
#
#   dji_open_lag1 dji_open_lag7 dji_open_lag14  ... dji_low_lag30 dji_low_lag90  \
# 0          None          None           None  ...          None          None
# 1    8.35000000          None           None  ...          None          None
# 2   -5.20000000          None           None  ...          None          None
# 3   -2.20000000          None           None  ...          None          None
# 4    0.14000000          None           None  ...          None          None
#
#   dji_low_lag365 dji_hilo_diff dji_hilo_diff_lag1 dji_hilo_diff_lag7  \
# 0           None          0E-8               None               None
# 1           None          0E-8               0E-8               None
# 2           None          0E-8               0E-8               None
# 3           None          0E-8               0E-8               None
# 4           None          0E-8               0E-8               None
#
#   dji_hilo_diff_lag14 dji_hilo_diff_lag30 dji_hilo_diff_lag90  \
# 0                None                None                None
# 1                None                None                None
# 2                None                None                None
# 3                None                None                None
# 4                None                None                None
#
#   dji_hilo_diff_lag365
# 0                 None
# 1                 None
# 2                 None
# 3                 None
# 4                 None
#
# [5 rows x 48 columns]

# %%
# CSV Import our input dataset
#data_df = pd.read_csv('us_data_df_v2.csv')
# Fill in the empty rows with "0". (4.5.2)
#data_df.fillna(0)
#data_df = data_df.dropna()
#data_df.head()

# %%
# convert to float
data_df[['dji_open', \
            'dji_open_lag1', \
            'dji_open_lag7', \
            'dji_open_lag14', \
            'dji_open_lag30', \
            'dji_open_lag90', \
            'dji_open_lag365', \
            'dji_close', \
            'dji_close_lag1', \
            'dji_close_lag7', \
            'dji_close_lag14', \
            'dji_close_lag30', \
            'dji_close_lag90', \
            'dji_close_lag365', \
            'dji_opcl_diff', \
            'dji_opcl_diff_lag1', \
            'dji_opcl_diff_lag7', \
            'dji_opcl_diff_lag14', \
            'dji_opcl_diff_lag30', \
            'dji_opcl_diff_lag90', \
            'dji_opcl_diff_lag365', \
            'dji_high', \
            'dji_high_lag1', \
            'dji_high_lag7', \
            'dji_high_lag14', \
            'dji_high_lag30', \
            'dji_high_lag90', \
            'dji_high_lag365', \
            'dji_low', \
            'dji_low_lag1', \
            'dji_low_lag7', \
            'dji_low_lag14', \
            'dji_low_lag30', \
            'dji_low_lag90', \
            'dji_low_lag365', \
            'dji_hilo_diff', \
            'dji_hilo_diff_lag1', \
            'dji_hilo_diff_lag7', \
            'dji_hilo_diff_lag14', \
            'dji_hilo_diff_lag30', \
            'dji_hilo_diff_lag90', \
            'dji_hilo_diff_lag365']] \
            = data_df[['dji_open', \
                        'dji_open_lag1', \
                        'dji_open_lag7', \
                        'dji_open_lag14', \
                        'dji_open_lag30', \
                        'dji_open_lag90', \
                        'dji_open_lag365', \
                        'dji_close', \
                        'dji_close_lag1', \
                        'dji_close_lag7', \
                        'dji_close_lag14', \
                        'dji_close_lag30', \
                        'dji_close_lag90', \
                        'dji_close_lag365', \
                        'dji_opcl_diff', \
                        'dji_opcl_diff_lag1', \
                        'dji_opcl_diff_lag7', \
                        'dji_opcl_diff_lag14', \
                        'dji_opcl_diff_lag30', \
                        'dji_opcl_diff_lag90', \
                        'dji_opcl_diff_lag365', \
                        'dji_high', \
                        'dji_high_lag1', \
                        'dji_high_lag7', \
                        'dji_high_lag14', \
                        'dji_high_lag30', \
                        'dji_high_lag90', \
                        'dji_high_lag365', \
                        'dji_low', \
                        'dji_low_lag1', \
                        'dji_low_lag7', \
                        'dji_low_lag14', \
                        'dji_low_lag30', \
                        'dji_low_lag90', \
                        'dji_low_lag365', \
                        'dji_hilo_diff', \
                        'dji_hilo_diff_lag1', \
                        'dji_hilo_diff_lag7', \
                        'dji_hilo_diff_lag14', \
                        'dji_hilo_diff_lag30', \
                        'dji_hilo_diff_lag90', \
                        'dji_hilo_diff_lag365']].astype(float)

data_df = pd.get_dummies(data_df, columns=["ri"])
data_df.head(20)
# Out:
#      intdate        cpi       gdp       inf       unp  dji_open  \
# 0   19701231  16.792044       NaN  5.838255       NaN    838.92
# 1   19710104  16.834236  1135.156  4.292767  5.994841    830.57
# 2   19710105  16.834236  1135.156  4.292767  5.997475    835.77
# 3   19710106  16.834236  1135.156  4.292767  6.007436    837.97
# 4   19710107  16.834236  1135.156  4.292767  6.121167    837.83
# 5   19710108  16.834236  1135.156  4.292767  6.194005    837.01
# 6   19710111  16.834236  1135.156  4.292767  6.095182    837.21
# 7   19710112  16.834236  1135.156  4.292767  5.978583    844.19
# 8   19710113  16.834236  1135.156  4.292767       NaN    841.11
# 9   19710114  16.834236  1135.156  4.292767       NaN    843.31
# 10  19710115  16.834236  1135.156  4.292767       NaN    845.70
# 11  19710118  16.834236  1135.156  4.292767       NaN    847.82
# 12  19710119  16.834236  1135.156  4.292767       NaN    849.47
# 13  19710120  16.834236  1135.156  4.292767       NaN    849.95
# 14  19710121  16.834236  1135.156  4.292767       NaN    854.74
# 15  19710122  16.834236  1135.156  4.292767       NaN    861.31
# 16  19710125  16.834236  1135.156  4.292767       NaN    865.62
# 17  19710126  16.834236  1135.156  4.292767       NaN    866.79
# 18  19710127  16.834236  1135.156  4.292767       NaN    860.83
# 19  19710128  16.834236  1135.156  4.292767       NaN    865.14
#
#     dji_open_lag1  dji_open_lag7  dji_open_lag14  dji_open_lag30  ...  \
# 0             NaN            NaN             NaN             NaN  ...
# 1            8.35            NaN             NaN             NaN  ...
# 2           -5.20            NaN             NaN             NaN  ...
# 3           -2.20            NaN             NaN             NaN  ...
# 4            0.14            NaN             NaN             NaN  ...
# 5            0.82            NaN             NaN             NaN  ...
# 6           -0.20            NaN             NaN             NaN  ...
# 7           -6.98          -5.27             NaN             NaN  ...
# 8            3.08         -10.54             NaN             NaN  ...
# 9           -2.20          -7.54             NaN             NaN  ...
# 10          -2.39          -7.73             NaN             NaN  ...
# 11          -2.12          -9.99             NaN             NaN  ...
# 12          -1.65         -12.46             NaN             NaN  ...
# 13          -0.48         -12.74             NaN             NaN  ...
# 14          -4.79         -10.55          -15.82             NaN  ...
# 15          -6.57         -20.20          -30.74             NaN  ...
# 16          -4.31         -22.31          -29.85             NaN  ...
# 17          -1.17         -21.09          -28.82             NaN  ...
# 18           5.96         -13.01          -23.00             NaN  ...
# 19          -4.31         -15.67          -28.13             NaN  ...
#
#     dji_low_lag365  dji_hilo_diff  dji_hilo_diff_lag1  dji_hilo_diff_lag7  \
# 0              NaN            0.0                 NaN                 NaN
# 1              NaN            0.0                 0.0                 NaN
# 2              NaN            0.0                 0.0                 NaN
# 3              NaN            0.0                 0.0                 NaN
# 4              NaN            0.0                 0.0                 NaN
# 5              NaN            0.0                 0.0                 NaN
# 6              NaN            0.0                 0.0                 NaN
# 7              NaN            0.0                 0.0                 0.0
# 8              NaN            0.0                 0.0                 0.0
# 9              NaN            0.0                 0.0                 0.0
# 10             NaN            0.0                 0.0                 0.0
# 11             NaN            0.0                 0.0                 0.0
# 12             NaN            0.0                 0.0                 0.0
# 13             NaN            0.0                 0.0                 0.0
# 14             NaN            0.0                 0.0                 0.0
# 15             NaN            0.0                 0.0                 0.0
# 16             NaN            0.0                 0.0                 0.0
# 17             NaN            0.0                 0.0                 0.0
# 18             NaN            0.0                 0.0                 0.0
# 19             NaN            0.0                 0.0                 0.0
#
#     dji_hilo_diff_lag14  dji_hilo_diff_lag30  dji_hilo_diff_lag90  \
# 0                   NaN                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   NaN                  NaN                  NaN
# 3                   NaN                  NaN                  NaN
# 4                   NaN                  NaN                  NaN
# 5                   NaN                  NaN                  NaN
# 6                   NaN                  NaN                  NaN
# 7                   NaN                  NaN                  NaN
# 8                   NaN                  NaN                  NaN
# 9                   NaN                  NaN                  NaN
# 10                  NaN                  NaN                  NaN
# 11                  NaN                  NaN                  NaN
# 12                  NaN                  NaN                  NaN
# 13                  NaN                  NaN                  NaN
# 14                  0.0                  NaN                  NaN
# 15                  0.0                  NaN                  NaN
# 16                  0.0                  NaN                  NaN
# 17                  0.0                  NaN                  NaN
# 18                  0.0                  NaN                  NaN
# 19                  0.0                  NaN                  NaN
#
#     dji_hilo_diff_lag365  ri_False  ri_True
# 0                    NaN         1        0
# 1                    NaN         1        0
# 2                    NaN         1        0
# 3                    NaN         1        0
# 4                    NaN         1        0
# 5                    NaN         1        0
# 6                    NaN         1        0
# 7                    NaN         1        0
# 8                    NaN         1        0
# 9                    NaN         1        0
# 10                   NaN         1        0
# 11                   NaN         1        0
# 12                   NaN         1        0
# 13                   NaN         1        0
# 14                   NaN         1        0
# 15                   NaN         1        0
# 16                   NaN         1        0
# 17                   NaN         1        0
# 18                   NaN         1        0
# 19                   NaN         1        0
#
# [20 rows x 49 columns]

# %%
data_df = data_df.dropna()
#data_df = data_df.fillna(0)

# %%
data_df.head(20)
# Out:
#        intdate        cpi       gdp        inf       unp  dji_open  \
# 505   19730102  18.015585  1377.490   6.177760  5.098482   1031.68
# 506   19730103  18.015585  1377.490   6.177760  5.016887   1043.80
# 507   19730104  18.015585  1377.490   6.177760  5.120382   1039.81
# 508   19730105  18.015585  1377.490   6.177760  4.961318   1047.49
# 509   19730108  18.015585  1377.490   6.177760  4.857442   1047.86
# 510   19730109  18.015585  1377.490   6.177760  4.911468   1047.11
# 511   19730110  18.015585  1377.490   6.177760  4.671672   1046.06
# 512   19730111  18.015585  1377.490   6.177760  4.869220   1051.70
# 513   19730112  18.015585  1377.490   6.177760  4.949730   1039.36
# 757   19740102  19.745419  1491.209  11.054805  5.213312    855.32
# 758   19740103  19.745419  1491.209  11.054805  5.123862    880.69
# 759   19740104  19.745419  1491.209  11.054805  5.140814    880.23
# 760   19740107  19.745419  1491.209  11.054805  5.597959    876.85
# 761   19740108  19.745419  1491.209  11.054805  5.517834    861.78
# 762   19740109  19.745419  1491.209  11.054805  6.032393    834.79
# 763   19740110  19.745419  1491.209  11.054805  6.085798    823.11
# 764   19740111  19.745419  1491.209  11.054805  6.660699    841.48
# 1010  19750102  22.065928  1616.116   9.143147  8.289681    632.04
# 1011  19750103  22.065928  1616.116   9.143147  8.723756    634.54
# 1012  19750106  22.065928  1616.116   9.143147  8.730855    637.20
#
#       dji_open_lag1  dji_open_lag7  dji_open_lag14  dji_open_lag30  ...  \
# 505          -11.66         -22.50            1.51          -33.26  ...
# 506          -12.12         -38.98           -7.53          -40.11  ...
# 507            3.99         -39.81           -6.62          -34.24  ...
# 508           -7.68         -43.28          -17.01          -42.45  ...
# 509           -0.37         -41.16          -22.80          -34.61  ...
# 510            0.75         -39.43          -19.87          -26.57  ...
# 511            1.05         -26.04          -32.81          -20.85  ...
# 512           -5.64         -20.02          -42.52          -33.94  ...
# 513           12.34           4.44          -34.54          -20.02  ...
# 757           -4.46         -27.21          -21.14           36.01  ...
# 758          -25.37         -61.96          -69.96          -18.03  ...
# 759            0.46         -65.42          -79.80          -35.33  ...
# 760            3.38         -39.29          -61.20          -21.87  ...
# 761           15.07         -10.77          -50.66           -7.78  ...
# 762           26.99          13.23           -5.30           -9.84  ...
# 763           11.68          27.75            6.46           -5.38  ...
# 764          -18.37          13.84          -13.37           -1.70  ...
# 1010         -15.80         -33.56          -36.69           -7.12  ...
# 1011          -2.50         -44.90          -38.17          -20.49  ...
# 1012          -2.66         -38.80          -44.43          -27.61  ...
#
#       dji_low_lag365  dji_hilo_diff  dji_hilo_diff_lag1  dji_hilo_diff_lag7  \
# 505          -145.00            0.0                 0.0                 0.0
# 506          -156.02            0.0                 0.0                 0.0
# 507          -150.94            0.0                 0.0                 0.0
# 508          -166.79            0.0                 0.0                 0.0
# 509          -175.85            0.0                 0.0                 0.0
# 510          -185.69            0.0                 0.0                 0.0
# 511          -187.63            0.0                 0.0                 0.0
# 512          -186.78            0.0                 0.0                 0.0
# 513          -189.33            0.0                 0.0                 0.0
# 757            61.37            0.0                 0.0                 0.0
# 758            29.76            0.0                 0.0                 0.0
# 759            40.22            0.0                 0.0                 0.0
# 760            58.51            0.0                 0.0                 0.0
# 761            72.67            0.0                 0.0                 0.0
# 762            97.78            0.0                 0.0                 0.0
# 763           103.74            0.0                 0.0                 0.0
# 764            85.22            0.0                 0.0                 0.0
# 1010          286.68            0.0                 0.0                 0.0
# 1011          298.48            0.0                 0.0                 0.0
# 1012          297.33            0.0                 0.0                 0.0
#
#       dji_hilo_diff_lag14  dji_hilo_diff_lag30  dji_hilo_diff_lag90  \
# 505                   0.0                  0.0                  0.0
# 506                   0.0                  0.0                  0.0
# 507                   0.0                  0.0                  0.0
# 508                   0.0                  0.0                  0.0
# 509                   0.0                  0.0                  0.0
# 510                   0.0                  0.0                  0.0
# 511                   0.0                  0.0                  0.0
# 512                   0.0                  0.0                  0.0
# 513                   0.0                  0.0                  0.0
# 757                   0.0                  0.0                  0.0
# 758                   0.0                  0.0                  0.0
# 759                   0.0                  0.0                  0.0
# 760                   0.0                  0.0                  0.0
# 761                   0.0                  0.0                  0.0
# 762                   0.0                  0.0                  0.0
# 763                   0.0                  0.0                  0.0
# 764                   0.0                  0.0                  0.0
# 1010                  0.0                  0.0                  0.0
# 1011                  0.0                  0.0                  0.0
# 1012                  0.0                  0.0                  0.0
#
#       dji_hilo_diff_lag365  ri_False  ri_True
# 505                    0.0         1        0
# 506                    0.0         1        0
# 507                    0.0         1        0
# 508                    0.0         1        0
# 509                    0.0         1        0
# 510                    0.0         1        0
# 511                    0.0         1        0
# 512                    0.0         1        0
# 513                    0.0         1        0
# 757                    0.0         0        1
# 758                    0.0         0        1
# 759                    0.0         0        1
# 760                    0.0         0        1
# 761                    0.0         0        1
# 762                    0.0         0        1
# 763                    0.0         0        1
# 764                    0.0         0        1
# 1010                   0.0         0        1
# 1011                   0.0         0        1
# 1012                   0.0         0        1
#
# [20 rows x 49 columns]

# %%
# drop ri_False and rename ri_True ri
data_df = data_df.drop({"ri_False"}, axis=1).rename(columns={'ri_True':'ri'})

data_df.dtypes
# Out:
# intdate                   int64
# cpi                     float64
# gdp                     float64
# inf                     float64
# unp                     float64
# dji_open                float64
# dji_open_lag1           float64
# dji_open_lag7           float64
# dji_open_lag14          float64
# dji_open_lag30          float64
# dji_open_lag90          float64
# dji_open_lag365         float64
# dji_close               float64
# dji_close_lag1          float64
# dji_close_lag7          float64
# dji_close_lag14         float64
# dji_close_lag30         float64
# dji_close_lag90         float64
# dji_close_lag365        float64
# dji_opcl_diff           float64
# dji_opcl_diff_lag1      float64
# dji_opcl_diff_lag7      float64
# dji_opcl_diff_lag14     float64
# dji_opcl_diff_lag30     float64
# dji_opcl_diff_lag90     float64
# dji_opcl_diff_lag365    float64
# dji_high                float64
# dji_high_lag1           float64
# dji_high_lag7           float64
# dji_high_lag14          float64
# dji_high_lag30          float64
# dji_high_lag90          float64
# dji_high_lag365         float64
# dji_low                 float64
# dji_low_lag1            float64
# dji_low_lag7            float64
# dji_low_lag14           float64
# dji_low_lag30           float64
# dji_low_lag90           float64
# dji_low_lag365          float64
# dji_hilo_diff           float64
# dji_hilo_diff_lag1      float64
# dji_hilo_diff_lag7      float64
# dji_hilo_diff_lag14     float64
# dji_hilo_diff_lag30     float64
# dji_hilo_diff_lag90     float64
# dji_hilo_diff_lag365    float64
# ri                        uint8
# dtype: object

# %% [markdown]
# ## Data Insights

# %%
# EDA on Data Table, showing 370 observations and 9 characteristics
data_df.shape
# Out:
# (355, 48)

# %%
# EDA to see label of each column
data_df.columns.values
# Out:
# array(['intdate', 'cpi', 'gdp', 'inf', 'unp', 'dji_open', 'dji_open_lag1',
#        'dji_open_lag7', 'dji_open_lag14', 'dji_open_lag30',
#        'dji_open_lag90', 'dji_open_lag365', 'dji_close', 'dji_close_lag1',
#        'dji_close_lag7', 'dji_close_lag14', 'dji_close_lag30',
#        'dji_close_lag90', 'dji_close_lag365', 'dji_opcl_diff',
#        'dji_opcl_diff_lag1', 'dji_opcl_diff_lag7', 'dji_opcl_diff_lag14',
#        'dji_opcl_diff_lag30', 'dji_opcl_diff_lag90',
#        'dji_opcl_diff_lag365', 'dji_high', 'dji_high_lag1',
#        'dji_high_lag7', 'dji_high_lag14', 'dji_high_lag30',
#        'dji_high_lag90', 'dji_high_lag365', 'dji_low', 'dji_low_lag1',
#        'dji_low_lag7', 'dji_low_lag14', 'dji_low_lag30', 'dji_low_lag90',
#        'dji_low_lag365', 'dji_hilo_diff', 'dji_hilo_diff_lag1',
#        'dji_hilo_diff_lag7', 'dji_hilo_diff_lag14', 'dji_hilo_diff_lag30',
#        'dji_hilo_diff_lag90', 'dji_hilo_diff_lag365', 'ri'], dtype=object)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 355 entries, 505 to 11865
# Data columns (total 48 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   intdate               355 non-null    int64
#  1   cpi                   355 non-null    float64
#  2   gdp                   355 non-null    float64
#  3   inf                   355 non-null    float64
#  4   unp                   355 non-null    float64
#  5   dji_open              355 non-null    float64
#  6   dji_open_lag1         355 non-null    float64
#  7   dji_open_lag7         355 non-null    float64
#  8   dji_open_lag14        355 non-null    float64
#  9   dji_open_lag30        355 non-null    float64
#  10  dji_open_lag90        355 non-null    float64
#  11  dji_open_lag365       355 non-null    float64
#  12  dji_close             355 non-null    float64
#  13  dji_close_lag1        355 non-null    float64
#  14  dji_close_lag7        355 non-null    float64
#  15  dji_close_lag14       355 non-null    float64
#  16  dji_close_lag30       355 non-null    float64
#  17  dji_close_lag90       355 non-null    float64
#  18  dji_close_lag365      355 non-null    float64
#  19  dji_opcl_diff         355 non-null    float64
#  20  dji_opcl_diff_lag1    355 non-null    float64
#  21  dji_opcl_diff_lag7    355 non-null    float64
#  22  dji_opcl_diff_lag14   355 non-null    float64
#  23  dji_opcl_diff_lag30   355 non-null    float64
#  24  dji_opcl_diff_lag90   355 non-null    float64
#  25  dji_opcl_diff_lag365  355 non-null    float64
#  26  dji_high              355 non-null    float64
#  27  dji_high_lag1         355 non-null    float64
#  28  dji_high_lag7         355 non-null    float64
#  29  dji_high_lag14        355 non-null    float64
#  30  dji_high_lag30        355 non-null    float64
#  31  dji_high_lag90        355 non-null    float64
#  32  dji_high_lag365       355 non-null    float64
#  33  dji_low               355 non-null    float64
#  34  dji_low_lag1          355 non-null    float64
#  35  dji_low_lag7          355 non-null    float64
#  36  dji_low_lag14         355 non-null    float64
#  37  dji_low_lag30         355 non-null    float64
#  38  dji_low_lag90         355 non-null    float64
#  39  dji_low_lag365        355 non-null    float64
#  40  dji_hilo_diff         355 non-null    float64
#  41  dji_hilo_diff_lag1    355 non-null    float64
#  42  dji_hilo_diff_lag7    355 non-null    float64
#  43  dji_hilo_diff_lag14   355 non-null    float64
#  44  dji_hilo_diff_lag30   355 non-null    float64
#  45  dji_hilo_diff_lag90   355 non-null    float64
#  46  dji_hilo_diff_lag365  355 non-null    float64
#  47  ri                    355 non-null    uint8
# dtypes: float64(46), int64(1), uint8(1)
# memory usage: 133.5 KB

# %% [markdown]
# - Data has only object values
# - No variable column has null or missing values

# %% [markdown]
# ## Summary Statistics

# %%
# EDA on Historical Price Table, beginning with basic statistics
data_df.describe()
# Out:
#             intdate         cpi           gdp         inf         unp  \
# count  3.550000e+02  355.000000    355.000000  355.000000  355.000000
# mean   1.995436e+07   63.136035   8835.516690    4.073798    6.339896
# std    1.334979e+05   25.884631   5610.106517    2.975878    1.620658
# min    1.973010e+07   18.015585   1377.490000   -0.355546    3.750499
# 25%    1.984011e+07   43.077079   3908.054000    2.270095    5.116190
# 50%    1.995011e+07   63.497555   7522.289000    3.156842    5.982123
# 75%    2.007011e+07   85.832240  14208.569000    4.827003    7.424400
# max    2.018011e+07  104.978124  20163.159000   13.549202   11.006776
#
#            dji_open  dji_open_lag1  dji_open_lag7  dji_open_lag14  \
# count    355.000000     355.000000     355.000000      355.000000
# mean    6967.755437      -0.587577     -23.355183      -91.115606
# std     6223.293594      83.744350     215.730679      242.181785
# min      632.040000    -319.050000    -787.940000     -860.130000
# 25%     1191.135000     -19.435000     -90.945000     -166.700000
# 50%     3867.410000      -2.990000     -25.470000      -44.430000
# 75%    10974.420000      15.280000      18.470000        1.575000
# max    25638.390000     369.190000    1353.230000     1237.370000
#
#        dji_open_lag30  ...  dji_low_lag90  dji_low_lag365  dji_hilo_diff  \
# count      355.000000  ...     355.000000      355.000000     355.000000
# mean      -190.881662  ...    -306.694451     -732.136732     118.720986
# std        389.519182  ...     851.153406     1610.586441     125.422630
# min      -1795.270000  ...   -3923.450000    -7385.290000       0.000000
# 25%       -210.060000  ...    -550.560000    -1576.555000      21.995000
# 50%        -91.970000  ...     -90.160000     -300.600000      72.300000
# 75%        -18.035000  ...      37.255000       60.155000     173.775000
# max       1462.100000  ...    2907.760000     4900.730000     845.430000
#
#        dji_hilo_diff_lag1  dji_hilo_diff_lag7  dji_hilo_diff_lag14  \
# count          355.000000          355.000000           355.000000
# mean            -2.878507          -27.542704            -4.745887
# std             58.528972           71.094683            62.527689
# min           -379.000000         -351.620000          -458.750000
# 25%            -12.750000          -42.475000           -17.930000
# 50%              0.000000          -10.140000            -1.830000
# 75%              7.600000            0.000000             7.165000
# max            293.610000          441.620000           291.200000
#
#        dji_hilo_diff_lag30  dji_hilo_diff_lag90  dji_hilo_diff_lag365  \
# count           355.000000           355.000000            355.000000
# mean            -13.468000           -12.372169            -10.024113
# std              92.829116            86.040183            104.573867
# min            -483.210000          -582.810000           -579.790000
# 25%             -27.000000           -28.150000            -29.575000
# 50%              -2.770000            -2.930000             -6.460000
# 75%               3.130000             3.735000              5.990000
# max             612.730000           470.260000            594.650000
#
#                ri
# count  355.000000
# mean     0.456338
# std      0.498793
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000
#
# [8 rows x 48 columns]

# %% [markdown]
# ### Key Observations
# - dataset comprises of 64,708 observations and 4 chracteriestics
# - out of which x is dependent variable and the remaining x are independent variables
# - Data needs to be redone.  Not capturing mean, Standard deviation etc

# %%
# EDA on Historical Price Table continued with pandas-profiling
#
#   UNCOMMENT FOR FINAL 
#
pp.ProfileReport(data_df)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=63.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Generate report structure', max=1.0, style=ProgressStyle(…

# %% [markdown]
# ## EDA Data Visualizations

# %%
#copy data_df into X and drop recession indicator
X = data_df.copy()
X = X.drop("ri", axis=1)

X.head()
# Out:
#       intdate        cpi      gdp      inf       unp  dji_open  dji_open_lag1  \
# 505  19730102  18.015585  1377.49  6.17776  5.098482   1031.68         -11.66
# 506  19730103  18.015585  1377.49  6.17776  5.016887   1043.80         -12.12
# 507  19730104  18.015585  1377.49  6.17776  5.120382   1039.81           3.99
# 508  19730105  18.015585  1377.49  6.17776  4.961318   1047.49          -7.68
# 509  19730108  18.015585  1377.49  6.17776  4.857442   1047.86          -0.37
#
#      dji_open_lag7  dji_open_lag14  dji_open_lag30  ...  dji_low_lag30  \
# 505         -22.50            1.51          -33.26  ...         -33.26
# 506         -38.98           -7.53          -40.11  ...         -40.11
# 507         -39.81           -6.62          -34.24  ...         -34.24
# 508         -43.28          -17.01          -42.45  ...         -42.45
# 509         -41.16          -22.80          -34.61  ...         -34.61
#
#      dji_low_lag90  dji_low_lag365  dji_hilo_diff  dji_hilo_diff_lag1  \
# 505         -64.49         -145.00            0.0                 0.0
# 506         -70.29         -156.02            0.0                 0.0
# 507         -69.46         -150.94            0.0                 0.0
# 508         -89.11         -166.79            0.0                 0.0
# 509         -88.50         -175.85            0.0                 0.0
#
#      dji_hilo_diff_lag7  dji_hilo_diff_lag14  dji_hilo_diff_lag30  \
# 505                 0.0                  0.0                  0.0
# 506                 0.0                  0.0                  0.0
# 507                 0.0                  0.0                  0.0
# 508                 0.0                  0.0                  0.0
# 509                 0.0                  0.0                  0.0
#
#      dji_hilo_diff_lag90  dji_hilo_diff_lag365
# 505                  0.0                   0.0
# 506                  0.0                   0.0
# 507                  0.0                   0.0
# 508                  0.0                   0.0
# 509                  0.0                   0.0
#
# [5 rows x 47 columns]

# %%
#copy recesison indicator and convert to data frame
y_cols = data_df["ri"] 

y = pd.DataFrame()

y["ri"] = y_cols
y.head()
# Out:
#      ri
# 505   0
# 506   0
# 507   0
# 508   0
# 509   0

# %%
y['ri'].value_counts()
# Out:
# 0    193
# 1    162
# Name: ri, dtype: int64

# %%
# Create X_train, X_test, y_train, y_test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y_cols, random_state=1)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs", max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.618

# %%
from sklearn.metrics import confusion_matrix, classification_report

# Calculating the confusion matrix.
cm = confusion_matrix(y_test, y_pred)

# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

cm_df

# %%
report = classification_report(y_test, y_pred)
print(report)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Creating a StandardScaler instance.
scaler = StandardScaler()
# Fitting the Standard Scaler with the training data.
X_scaler = scaler.fit(X_train)
# Scaling the data.
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a random forest classifier. (17.8.3)
rf_model = RandomForestClassifier(n_estimators=128, random_state=78, max_depth=4) 

# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# Making predictions using the testing data.
predictions = rf_model.predict(X_test_scaled)

# %%
# Calculating the confusion matrix.
cm = confusion_matrix(y_test, predictions)

# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

cm_df

# %%
# Calculating the accuracy score.
acc_score = accuracy_score(y_test, predictions)

# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))

# %%
# Calculate feature importance in the Random Forest model.
importances = rf_model.feature_importances_

# We can sort the features by their importance.
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)

# %%
import graphviz
from sklearn import tree
#for tree_in_forest in rf_model.estimators_:
classification_tree = tree.export_graphviz(rf_model.estimators_[0], out_file=None, 
                      feature_names=X.columns,  
                      class_names=["0","1"],  
                      filled=True)
graph = graphviz.Source(classification_tree) 
graph

# %% [markdown]
# ## Check for missing values

# %%
import seaborn as sns
sns.heatmap(data_df.isnull(),cbar=False,yticklabels=False,cmap = 'viridis')

# %% [markdown]
# ## Checking Correlation

# %%
#plt.figure(figsize=(10,10))
figure.Figure(figsize=(10,10))
sns.heatmap(data_df.corr(),cmap='Blues',annot=False)

# %%
#Quality correlation matrix

matplotlib.rcParams.update({'font.size': 6})

k = 17# number of variables for heatmap
cols = data_df.corr().nlargest(k, 'inf')['inf'].index
cm = data_df[cols].corr()
#plt.figure(figsize=(10,10))
figure.Figure(figsize=(10,100))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %% [markdown]
# ## Checking for outliers

# %%
import matplotlib.pyplot as plt

l = data_df.columns.values
number_of_columns=12
number_of_rows = len(l)-1/number_of_columns
plt.figure(figsize=(number_of_columns,.75
                    *number_of_rows))
for i in range(0,len(l)):
    plt.plot(number_of_rows + 1,number_of_columns,i+1)
    sns.set_style('whitegrid')
    sns.boxplot(data_df[l[i]],color='red',orient='h')
    plt.tight_layout()

# %% [markdown]
# ## Checking skewness

# %%
plt.figure(figsize=(2*number_of_columns,5*number_of_rows))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.distplot(data_df[l[i]],kde=True)
